# %% [markdown]
# # DP-FL for Diabetic Retinopathy
# This notebook allows you to run the baseline and federated learning training scripts for the DP-FL project on Google Colab.

# %% [markdown]
# ## 1. Mount Google Drive
# Run the cell below to mount your Google Drive. Make sure you have uploaded the `dp_fl_dr` folder to your Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Navigate to the Project Directory
# Update the `PROJECT_DIR` path below to point to where you uploaded the `dp_fl_dr` folder in your Drive.

# %%
import os

# CHANGE THIS to your folder's path in Google Drive
PROJECT_DIR = '/content/drive/MyDrive/dp_fl_dr'

if os.path.exists(PROJECT_DIR):
    # %cd {PROJECT_DIR}
    print(f"Current working directory: {os.getcwd()}")
else:
    print(f"Directory {PROJECT_DIR} not found. Please check the path.")

# %% [markdown]
# ## 3. Install Dependencies
# Google Colab comes pre-installed with most of the required libraries (PyTorch, Pandas, Scikit-Learn, etc.). We run this cell just to be sure.

# %%
# !pip install -q pandas scikit-learn matplotlib torchvision torch numpy

# %% [markdown]
# ## 4. Run Baseline Training
# Train centralized baseline models (AlexNet, ResNet50, SqueezeNet, VGG16) for both binary and 5-class grading.

# %%
# !python train_baseline.py

# %% [markdown]
# ## 5. Run FedAvg Training
# Run the Federated Averaging simulation with ResNet50 (without Differential Privacy).

# %%
# !python train_fedavg.py
